# %%
# Edit this cell to print out your name.
print "My name is %s" % ("Jeff Petteys")
# Out:
# My name is Jeff Petteys

# %% [markdown]
# # Predicting the weather
#
# ***For all of the questions in this project, assume that 1 month = 30 days.***

# %% [markdown]
# ## Problem 1 (20 pts)
#
# Suppose there is a 20% chance it will rain on any given day in a month. What are the odds that that rains on one and only one day in a month.
#
# Work this problem out a*nalytically* (with pen and paper, using a formula) and write it up in your final document.
#
# Here you should solve the same problem *numerically* using a Monte Carlo approach, similar to how we approached the birthday problem in class.
#
# Make sure that both approaches give you a similar result.

# %%
# analytical column

def prob_analytical(days_in_month):
    
    x = .8 ** (days_in_month - 1) * .2 * 30 * 100
    
    return x
                                        #Rain should occur on one day AND rain should not
                                        #occur or any other day which is 0.2* 1 * 0.8 ** 29. 
                                        #However, I made it so the number
                                        # Of days in a month can change
                                        # .8 ^ 29 is because thats for every other day
print prob_analytical(30)
# Out:
# 0.928455029464

# %%
# monte carlo

import numpy as np
from numpy import random #random numbers to be generated


ndays = 30   # number of days in a month for this problem

def prob_numer(ndays):
    
    x = random.random()   # random number
    
    if x is .2 > x < 1.0:   # If x is higher than 20% (liklihood of it raining) print false, meaning it wont rain 
        
        will_it_rain = False
    else: 
        will_it_rain = True
        
    return will_it_rain

print prob_numer(ndays)
# Out:
# True

# %%
def prob_numer():
    
    x = random.random()
# rain = False 
    
    if x is .2 > x < 1.0:   
     
     
        will_it_rain = False
    else:
        will_it_rain = True
 
    return will_it_rain

def prob_ofitraining():
    
    for r in range(0,ndays):
        
        s = prob_numer()
        
        randomdates.append(s)
        
        if sum(randomdates) == 1:
            return "There is only one day in this month where it rains."
        else:
            return "There's more than one day in this month where it rains."
    
            return prob_ofitraining
        
print prob_ofitraining
# Out:
# <function prob_ofitraining at 0x000000000F7B2C18>

# %% [markdown]
# ## Problem 2 (20 pts)
#
# Suppose there is a 10% chance that it will rain on any given day in a month. What are the odds that it rains at least 8 days (in any order) that month?
#
# Work this problem out *numerically* using a Monte Carlo approach.

# %%
randomdates = []

def prob_numer(ndays):
    
    x = random.random()   # random number
    
    if x is .1 > x < 1.0:   # If x is higher than 20% (liklihood of it raining) print false, meaning it wont rain 
        
        will_it_rain = False
    else: will_it_rain = True
        
    return will_it_rain

print prob_numer(ndays)



def prob_ofitraining():
    
    for r in range(0,ndays):
        
        s = prob_numer(ndays)
        
        randomdates.append(x)
        
        if randomdates >= 8:
            return "There are 8 or more days in this month where it rains."
        else:
            return "During this month, it rained 7 times or less."
        
print prob_ofitraining()
# Out:
# True
# There are 8 or more days in this month where it rains.

# %%
# Your code here
#DISREGARD
numbers = [] # list of numbers to see if they're either below or above 10%


    
n = random.random()
    
if n is 0 < n < .1:
        
    numbers.append(n)
        
   
    print numbers

# %%
#Testing it with values

nmonths = 1000

randommonths2 = []

randommonths2.append(prob_ofitraining)

sumoflist = sum(randommonths)

print sumoflist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-226-0710d26c92af> in <module>()
#       7 randommonths2.append(prob_ofitraining)
#       8
# ----> 9 sumoflist = sum(randommonths)
#      10
#      11 print sumoflist
#
# TypeError: unsupported operand type(s) for +: 'int' and 'function'

# %% [markdown]
# ## Problem 3
#
# ### 3a (20 pts)
#
# Suppose that if it rains one day, the odds of a certain amount of rainfall *on that day* are
#
# * 1 cm   20%
# * 2 cm   30%
# * 3 cm   30%
# * 4 cm   10%
# * 5 cm   10%
#
# However the odds of it raining are dependent on if it rained the day before.
#
# * If it is the first day of the month, there is a 10% chance of rain.
# * If it rained 1 day before, but not 2 days before, there is a 20% chance of rain.
# * If it rained both of the 2 days before, but not the 3rd day before, there is a 25% chance of rain.
# * If it rained for the 3 days (or more) before, there is a 5% chance of rain.
# * Otherwise, there is a 10% chance of rain
#
# What are the odds that there are at least 10 cm of rain in a given month?
#
# Work this problem out using a Monte Carlo approach.

# %%
# Your code here

# %% [markdown]
# ### 3b (10 pts)
#
# Make a histogram of the distribtion of expected rainfall values. You can get this from your Monte Carlo trials.
#
# Make sure you label everything clearly.

# %%
# Your code here?

values = []

x = 0 + 5*random.random(200)   # random values of rain between 0 and 5 cm

#print values

values.append(x)


import matplotlib.pylab as plt

# %matplotlib notebook

plt.figure()

plt.hist(values,bins=10,range=(0,5),color="#00a8cc") 

plt.xlabel("Centimeters of Rainfall/ Day",fontsize=18)
plt.ylabel("Number of Times Occurred",fontsize=18)    

plt.xlim(0,5)
plt.ylim(0,40)

plt.title("Distribution of Rainfall Values")

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %%
#print values

# %% [markdown]
# ### 3c (10 pts)
#
# What is the average amount of rain to fall in any given month?

# %%
# Your code here?

average = sum(values)/(200)

print average
# Out:
# [  2.28793412e-02   8.60334787e-03   8.71043975e-03   1.07577863e-02
#    2.25973502e-02   9.00137156e-04   1.30385510e-02   1.43593064e-02
#    1.78564243e-02   5.41381197e-03   2.42727193e-02   9.84094977e-03
#    1.82654986e-02   1.34038185e-02   7.12374105e-04   2.18575898e-02
#    1.55441969e-02   2.23715557e-02   1.02797388e-02   5.18377596e-04
#    1.81648056e-02   3.34039947e-03   1.89458580e-02   1.21591247e-02
#    1.87508144e-02   8.86476266e-03   1.10335092e-03   8.04352090e-03
#    2.30579304e-02   2.07494952e-02   2.14514608e-02   1.14462530e-02
#    2.16401908e-02   8.38240864e-03   2.06982088e-02   3.81025984e-03
#    1.91802215e-02   2.19314535e-02   2.21733179e-02   1.71900208e-02
#    1.57667762e-02   8.05469873e-03   1.31298606e-02   1.87125619e-02
#    1.18737674e-02   2.44063248e-02   1.39074662e-02   3.33027963e-03
#    1.91780444e-02   1.65562161e-03   2.46287496e-02   2.09456846e-02
#    1.08446477e-02   5.44330037e-03   4.94291815e-04   5.27488635e-03
#    5.77508938e-03   9.42605211e-04   1.67860313e-02   1.67841255e-02
#    1.92063016e-02   1.15985082e-02   5.20586027e-03   1.27055605e-02
#    3.82985344e-04   1.00501254e-02   2.21411111e-02   6.33739379e-04
#    1.79924855e-02   1.64602443e-03   6.51553876e-03   7.25354440e-03
#    1.47769273e-02   3.35520599e-03   1.75927031e-02   1.50615763e-02
#    1.50733537e-02   1.57562395e-02   1.03391298e-02   6.97163332e-03
#    7.90412465e-03   5.64046763e-03   1.19761124e-02   1.57944622e-02
#    1.52754040e-02   6.86816959e-03   1.61603600e-03   8.88244093e-03
#    1.25928126e-04   1.85116446e-02   1.30865082e-02   6.43302828e-04
#    1.80708085e-02   2.06148569e-02   1.44809503e-02   3.42969982e-03
#    1.22432301e-02   2.34458149e-02   2.24976298e-02   1.38990197e-02
#    2.27337816e-02   1.20367550e-02   2.40229464e-02   1.04997548e-02
#    1.17021585e-02   1.68864105e-02   1.59915052e-02   1.60728707e-02
#    7.59877899e-04   5.62835282e-03   2.32448064e-02   9.49336327e-03
#    4.01179539e-03   2.34486941e-02   2.14875823e-02   1.86237675e-02
#    1.97831970e-02   8.58570532e-03   1.91466932e-02   4.92355086e-03
#    1.04901618e-02   2.36570192e-02   2.79639653e-03   9.04495954e-03
#    2.29033494e-02   1.57354035e-02   3.40763255e-03   1.07080448e-03
#    2.48606272e-02   6.17569552e-03   2.19753092e-02   1.43224390e-02
#    5.27032418e-03   1.80017745e-02   1.15764307e-03   1.99664038e-02
#    1.06988561e-02   1.89569202e-03   9.83590368e-03   1.96269353e-02
#    1.72423037e-02   1.92493433e-02   8.00791276e-03   2.05379253e-02
#    3.31764177e-03   1.25599429e-02   4.98232315e-03   2.25120560e-02
#    1.33250497e-03   1.34973123e-02   2.36959330e-02   2.02091681e-02
#    5.26102801e-03   1.63594659e-02   8.63165990e-03   3.28137059e-03
#    1.52276144e-03   2.13653886e-02   3.22009755e-03   1.83549618e-02
#    1.56008063e-02   7.23886735e-03   1.12141410e-02   2.37015082e-02
#    1.09291169e-02   1.43585338e-02   1.42773649e-02   1.47935881e-02
#    6.35531365e-05   1.35698035e-02   5.56618431e-03   1.79090021e-02
#    2.25873763e-02   2.42119959e-02   1.62939024e-02   1.77163004e-02
#    1.19439087e-02   1.80010277e-02   6.30312952e-03   1.72051074e-03
#    1.32487027e-02   1.34473830e-02   7.86291572e-03   8.00983305e-03
#    8.35674977e-03   1.14992486e-02   3.73243803e-04   1.33091482e-02
#    1.58858283e-02   2.10965492e-02   1.57655351e-02   2.44262276e-02
#    1.11475816e-02   2.04175031e-02   1.38057541e-02   2.39569049e-02
#    4.32417253e-03   2.05339720e-02   1.07881000e-02   9.79782780e-03]

# %% [markdown]
# ### 3d (20 pts)
#
# Once you find the average value, someone might ask you for the uncertainty (some people also refer to uncertainty as the "*error*") on your prediction. That can be tricky to calculate, so often what is given is just a *range* of possible values. "We estimate the rainfall to be between X cm and Y cm." The question is, how to decide what that range is.
#
# The way this is often done is to find the middle 95% of the trial values (from your Monte Carlo run) and then use the low-edge and the high-edge of that range. If you're concerned about the middle 95%, then 2.5% of the values are below them and 2.5% of all the values are above them. The rainfall values at those edges are what you use for the ranges to quote.
#
# This is what people mean when they say, "I'm 95% confident that the rainfall will be between X and Y", and when you write it up for the LaTeX document, you should also quote it this way.
#
# *Hint!* This part becomes much easier if you sort all the values using any of the numpy/Python sort functions you can read about online. When you sort them, you should be able to find what rainfall is at the edge for the lower 2.5% and the higher 2.5%.

# %%
# Your code here

sorted(values)

